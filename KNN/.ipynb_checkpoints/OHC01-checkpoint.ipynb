# %%
import pandas as pd

# ----- plot tools -----
import matplotlib.pyplot as plt
import seaborn as sns

# ----- sklean -----
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV, cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel("CarPrice.xlsx")
data.head(10)
# Out:
#                       ยี่ห้อ ปีที่ออกขายครั้งแรก ราคาขายมือสอง  \
# 0                     Suzuki                2007         60000
# 1                     Suzuki                2007        135000
# 2       Hyundai Verna 1.6 SX                2012        600000
# 3                 Mitsubishi                2017        250000
# 4                      Honda                2014        450000
# 5                     Suzuki                2007        140000
# 6  Hyundai Xcent 1.2 Kappa S                2016        550000
# 7                       Tata                2014        240000
# 8   Hyundai Creta 1.6 VTVT S                2015        850000
# 9                     Suzuki                2017        365000
#
#    กิโลเมตรที่ขับไปแล้ว ประเภทเชื้อเพลิง ประเภทผู้ขายรถ ประเภทเกียร์  \
# 0               70000.0           เบนซิน  เจ้าของขายเอง       Manual
# 1               50000.0           เบนซิน  เจ้าของขายเอง       Manual
# 2              100000.0            ดีเซล  เจ้าของขายเอง       Manual
# 3               46000.0           เบนซิน  เจ้าของขายเอง       Manual
# 4              141000.0            ดีเซล  เจ้าของขายเอง       Manual
# 5              125000.0           เบนซิน  เจ้าของขายเอง       Manual
# 6               25000.0           เบนซิน  เจ้าของขายเอง       Manual
# 7               60000.0           เบนซิน  เจ้าของขายเอง       Manual
# 8               25000.0           เบนซิน  เจ้าของขายเอง       Manual
# 9               78000.0              CNG  เจ้าของขายเอง       Manual
#
#    จำนวนเจ้าของรถในอดีต
# 0                   3.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   2.0
# 5                   1.0
# 6                   1.0
# 7                   2.0
# 8                   1.0
# 9                   1.0

# %%
data.tail(10)
# Out:
#     ยี่ห้อ ปีที่ออกขายครั้งแรก ราคาขายมือสอง  กิโลเมตรที่ขับไปแล้ว  \
# 499   Ford                2012        425000               81632.0
# 500   Ford                2016        600000              155201.0
# 501    NaN                 NaN           NaN                   NaN
# 502    NaN                 NaN           NaN                   NaN
# 503    NaN                 NaN           NaN                   NaN
# 504    NaN                 NaN           NaN                   NaN
# 505    NaN                 NaN                                 NaN
# 506    NaN                 NaN           NaN                   NaN
# 507    NaN                 NaN           NaN                   NaN
# 508    NaN                               NaN                   NaN
#
#     ประเภทเชื้อเพลิง ประเภทผู้ขายรถ ประเภทเกียร์  จำนวนเจ้าของรถในอดีต
# 499            ดีเซล       เต๊นท์รถ       Manual                   1.0
# 500            ดีเซล       เต๊นท์รถ       Manual                   1.0
# 501              NaN            NaN          NaN                   NaN
# 502              NaN            NaN          NaN                   NaN
# 503              NaN            NaN          NaN                   NaN
# 504              NaN            NaN          NaN                   NaN
# 505              NaN            NaN          NaN                   NaN
# 506              NaN            NaN          NaN                   NaN
# 507              NaN            NaN          NaN                   NaN
# 508              NaN            NaN          NaN                   NaN

# %% [markdown]
# ___

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## handling missing values

# %%
data.dropna(inplace=True)
data.shape[0]
# Out:
# 501

# %% [markdown]
# ## Duplicated data

# %%
data.drop_duplicates(inplace = True)
data.shape[0]
# Out:
# 487

# %%
data = data.rename(columns={"ยี่ห้อ" : "Brand", 
                            "ประเภทเชื้อเพลิง" : "Fuel_Type",
                            "ประเภทผู้ขายรถ" : "Seller_Type",
                            "ประเภทเกียร์" : "Gear_Type",
                            "กิโลเมตรที่ขับไปแล้ว" : "Mileage",
                            "ปีที่ออกขายครั้งแรก" : "First_Sell_Year",
                            "ราคาขายมือสอง" : "Secondhand_Price",
                            "จำนวนเจ้าของรถในอดีต" : "Past_Owner"
                           })
data
# Out:
#                     Brand First_Sell_Year Secondhand_Price   Mileage  \
# 0                  Suzuki            2007            60000   70000.0
# 1                  Suzuki            2007           135000   50000.0
# 2    Hyundai Verna 1.6 SX            2012           600000  100000.0
# 3              Mitsubishi            2017           250000   46000.0
# 4                   Honda            2014           450000  141000.0
# ..                    ...             ...              ...       ...
# 496                  Ford            2019           700000   12586.0
# 497                  Fiat            2018           650000   38083.0
# 498                  Ford            2012           400000   55328.0
# 499                  Ford            2012           425000   81632.0
# 500                  Ford            2016           600000  155201.0
#
#     Fuel_Type    Seller_Type Gear_Type  Past_Owner
# 0      เบนซิน  เจ้าของขายเอง    Manual         3.0
# 1      เบนซิน  เจ้าของขายเอง    Manual         1.0
# 2       ดีเซล  เจ้าของขายเอง    Manual         1.0
# 3      เบนซิน  เจ้าของขายเอง    Manual         1.0
# 4       ดีเซล  เจ้าของขายเอง    Manual         2.0
# ..        ...            ...       ...         ...
# 496    เบนซิน       เต๊นท์รถ    Manual         1.0
# 497     ดีเซล       เต๊นท์รถ    Manual         1.0
# 498     ดีเซล       เต๊นท์รถ    Manual         2.0
# 499     ดีเซล       เต๊นท์รถ    Manual         1.0
# 500     ดีเซล       เต๊นท์รถ    Manual         1.0
#
# [487 rows x 8 columns]

# %%
data.nunique()
# Out:
# Brand               122
# First_Sell_Year      24
# Secondhand_Price    167
# Mileage             158
# Fuel_Type             4
# Seller_Type           2
# Gear_Type             2
# Past_Owner            3
# dtype: int64

# %% [markdown]
# ### Feature : "Brand"

# %%
data.Brand.unique()
# Out:
# array(['Suzuki', 'Hyundai Verna 1.6 SX', 'Mitsubishi', 'Honda',
#        'Hyundai Xcent 1.2 Kappa S', 'Tata', 'Hyundai Creta 1.6 VTVT S',
#        'Chevrolet', 'Toyota', 'Hyundai Venue SX Opt ดีเซล',
#        'Mercedes-Benz', 'Audi', 'Skoda', 'Toyota ',
#        'Hyundai i10 Magna 1.1L', 'BMW', 'Hyundai Elantra CRDi S',
#        'Mahindra Scorpio 1.99 S10', 'Mahindra Scorpio LX',
#        'Hyundai Santro Xing GLS', 'Hyundai Grand i10 1.2 Kappa Asta',
#        'Suzukii', 'Hyundai i20 Sportz 1.4 CRDi',
#        'Hyundai i20 2015-2017 Sportz Option 1.4 CRDi',
#        'Mahindra Jeep CL 500 MDI', 'Hyundai EON Magna Plus',
#        'Mahindra Scorpio 1.99 S6 Plus', 'Ford', 'Hyundai i10 Sportz 1.2',
#        'Hyundai Getz GLS', 'Nissan', 'Hyundai Grand i10 CRDi Sportz',
#        'Hyundai Elite i20 ดีเซล Era', 'Hyundai Creta 1.6 SX Option',
#        'Mahindra XUV500 W8 2WD', 'Hyundai Santro Xing XO',
#        'Mahindra Bolero 2011-2019 SLE', 'Fiat', 'Volkswagen',
#        'Volvo V40 D3 R Design', 'Mahindra Bolero Power Plus SLX',
#        'Hyundai Sonata CRDi M/T', 'Mahindra Xylo D4',
#        'Hyundai Elite i20 Sportz Plus Dual Tone BSIV',
#        'Mahindra Xylo E4 BS III', 'Hyundai Creta 1.4 CRDi S',
#        'Hyundai Verna 1.6 VTVT AT S Option', 'Mahindra Scorpio LX BSIV',
#        'Hyundai Creta 1.6 CRDi SX', 'Hyundai i10 Sportz 1.1L',
#        'Hyundai EON Era Plus', 'Hyundai Santro LP zipPlus', 'SuzukiI',
#        'Hyundai i20 Magna 1.2', 'Hyundai i20 1.2 Asta',
#        'Hyundai i20 Asta 1.4 CRDi', 'Hyundai Santro LE',
#        'Hyundai Santro Xing XL eRLX Euro III', 'Hyundai Getz 1.3 GLS',
#        'Mahindra Quanto C8', 'Hyundai i10 Asta AT',
#        'Hyundai Santro Xing XG', 'Hyundai i20 Asta', 'Mahindra Xylo E4',
#        'Hyundai i20 1.2 Sportz', 'Hyundai EON Era Plus Option',
#        'Mahindra XUV500 W6 2WD', 'Mahindra XUV300 W8 Option',
#        'Hyundai i20 Magna 1.4 CRDi (ดีเซล)', 'Hyundai Verna i (เบนซิน)',
#        'Mahindra Renault Logan 1.5 DLS', 'Mahindra Scorpio S11 BSIV',
#        'Hyundai i20 Active 1.2 SX', 'Hyundai Grand i10 Magna',
#        'Hyundai i10 Era', 'Hyundai Grand i10 1.2 CRDi Asta',
#        'Hyundai Elite i20 Asta Option BSIV',
#        'Hyundai Grand i10 CRDi Magna', 'Hyundai Santro Xing GL Plus',
#        'Hyundai i20 1.4 Sportz', 'Hyundai i20 1.4 Magna ABS',
#        'Hyundai Getz GL', 'Hyundai i20 1.2 Spotz', 'Hyundai i20 Asta (o)',
#        'Hyundai Verna 1.6 SX CRDi (O)', 'Mahindra Xylo D2 BSIV',
#        'Mahindra Bolero SLX 2WD BSIII',
#        'Mahindra Scorpio VLS AT 2.2 mHAWK', 'Mahindra Bolero SLX',
#        'Mahindra XUV500 W11 Option AWD', 'Mahindra Marazzo M8 8Str',
#        'Hyundai EON 1.0 Kappa Magna Plus', 'Hyundai Verna 1.4 VTVT',
#        'Mahindra Bolero Power Plus Plus AC BSIV PS',
#        'Hyundai Grand i10 1.2 Kappa Sportz Option',
#        'Hyundai Verna CRDi 1.6 EX', 'Mahindra Scorpio 2.6 Turbo 9 Str',
#        'Hyundai Grand i10 Sportz', 'Mahindra Scorpio S7 140 BSIV',
#        'Hyundai Xcent 1.1 CRDi Base', 'Mahindra Scorpio SLE BSIV',
#        'Hyundai Santro Xing GLS CNG', 'Hyundai i20 Sportz เบนซิน',
#        'Hyundai i20 Active 1.2 S', 'Hyundai Santro GLS I - Euro I',
#        'Mahindra Scorpio REV 116', 'Mahindra XUV500 W11 AT BSIV',
#        'Mahindra Supro VX 8 Str', 'Mahindra KUV 100 D75 K2',
#        'Hyundai Santro Era', 'Hyundai Verna 1.6 CRDI',
#        'Hyundai EON D Lite Plus', 'Hyundai i20 Asta 1.2',
#        'Mahindra TUV 300 T4 Plus', 'Hyundai Santro Magna BSIV',
#        'Mahindra XUV500 W11 Option AT AWD', 'Hyundai Verna CRDi',
#        'Hyundai i10 Era 1.1', 'Hyundai EON LPG Magna Plus', 'Volkswagen ',
#        'Mahindra Bolero DI DX 7 Seater',
#        'Hyundai Santro Xing GLS Audio LPG'], dtype=object)

# %%
data.Brand.str.split().str[0].unique()
# Out:
# array(['Suzuki', 'Hyundai', 'Mitsubishi', 'Honda', 'Tata', 'Chevrolet',
#        'Toyota', 'Mercedes-Benz', 'Audi', 'Skoda', 'BMW', 'Mahindra',
#        'Suzukii', 'Ford', 'Nissan', 'Fiat', 'Volkswagen', 'Volvo',
#        'SuzukiI'], dtype=object)

# %%
data.loc[(data["Brand"] == "Suzukii") | (data["Brand"] == "SuzukiI"), "Brand"] = "Suzuki"

# %%
data["Model"] = data['Brand'].str.split().str[1]
data.head(5)
# Out:
#                   Brand First_Sell_Year Secondhand_Price   Mileage Fuel_Type  \
# 0                Suzuki            2007            60000   70000.0    เบนซิน
# 1                Suzuki            2007           135000   50000.0    เบนซิน
# 2  Hyundai Verna 1.6 SX            2012           600000  100000.0     ดีเซล
# 3            Mitsubishi            2017           250000   46000.0    เบนซิน
# 4                 Honda            2014           450000  141000.0     ดีเซล
#
#      Seller_Type Gear_Type  Past_Owner  Model
# 0  เจ้าของขายเอง    Manual         3.0    NaN
# 1  เจ้าของขายเอง    Manual         1.0    NaN
# 2  เจ้าของขายเอง    Manual         1.0  Verna
# 3  เจ้าของขายเอง    Manual         1.0    NaN
# 4  เจ้าของขายเอง    Manual         2.0    NaN

# %%
data.loc[ :,'Brand'] = data['Brand'].str.split().str[0]
data.head(5)
# Out:
#         Brand First_Sell_Year Secondhand_Price   Mileage Fuel_Type  \
# 0      Suzuki            2007            60000   70000.0    เบนซิน
# 1      Suzuki            2007           135000   50000.0    เบนซิน
# 2     Hyundai            2012           600000  100000.0     ดีเซล
# 3  Mitsubishi            2017           250000   46000.0    เบนซิน
# 4       Honda            2014           450000  141000.0     ดีเซล
#
#      Seller_Type Gear_Type  Past_Owner  Model
# 0  เจ้าของขายเอง    Manual         3.0    NaN
# 1  เจ้าของขายเอง    Manual         1.0    NaN
# 2  เจ้าของขายเอง    Manual         1.0  Verna
# 3  เจ้าของขายเอง    Manual         1.0    NaN
# 4  เจ้าของขายเอง    Manual         2.0    NaN

# %%
top_Brand = data["Brand"].str.split().str[0].value_counts().head(15)

plt.figure(figsize=(10, 6))
sns.barplot(
    x=top_Brand.values, 
    y=top_Brand.index, 
    palette="RdBu",
)
plt.title(f'Top 15 Brand')
plt.xlabel("Frequency")
plt.ylabel("Brand")
plt.tight_layout()
#
plt.savefig("Top_15_Brand.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# add new feature : Age 
data["Age"] = 2024 - data["First_Sell_Year"]

data.Past_Owner = data.Past_Owner.astype(int)

# %% [markdown]
# ## Handling Outler

# %%
num_cols = ["Secondhand_Price", "Mileage","Age"]
fig = plt.figure(figsize=[13,3])

for idx, col in enumerate(num_cols):  # วนลูปไปตามคอลัมน์ใน num_cols
    plt.subplot(1, 3, idx+1)  # สร้าง subplot ตามตำแหน่ง
    sns.boxplot(x=col, data=data)
    plt.title(f"Boxplot for {col}")

plt.tight_layout()
#
plt.savefig("Boxplot_feature.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
data = data[(data["Secondhand_Price"] < data["Secondhand_Price"].quantile(0.99)) &
            (data["Mileage"] < data["Mileage"].quantile(0.99))]

# %%
data
# Out:
#           Brand First_Sell_Year Secondhand_Price   Mileage Fuel_Type  \
# 0        Suzuki            2007            60000   70000.0    เบนซิน
# 1        Suzuki            2007           135000   50000.0    เบนซิน
# 2       Hyundai            2012           600000  100000.0     ดีเซล
# 3    Mitsubishi            2017           250000   46000.0    เบนซิน
# 4         Honda            2014           450000  141000.0     ดีเซล
# ..          ...             ...              ...       ...       ...
# 496        Ford            2019           700000   12586.0    เบนซิน
# 497        Fiat            2018           650000   38083.0     ดีเซล
# 498        Ford            2012           400000   55328.0     ดีเซล
# 499        Ford            2012           425000   81632.0     ดีเซล
# 500        Ford            2016           600000  155201.0     ดีเซล
#
#        Seller_Type Gear_Type  Past_Owner  Model Age
# 0    เจ้าของขายเอง    Manual           3    NaN  17
# 1    เจ้าของขายเอง    Manual           1    NaN  17
# 2    เจ้าของขายเอง    Manual           1  Verna  12
# 3    เจ้าของขายเอง    Manual           1    NaN   7
# 4    เจ้าของขายเอง    Manual           2    NaN  10
# ..             ...       ...         ...    ...  ..
# 496       เต๊นท์รถ    Manual           1    NaN   5
# 497       เต๊นท์รถ    Manual           1    NaN   6
# 498       เต๊นท์รถ    Manual           2    NaN  12
# 499       เต๊นท์รถ    Manual           1    NaN  12
# 500       เต๊นท์รถ    Manual           1    NaN   8
#
# [477 rows x 10 columns]

# %% [markdown]
# ___

# %% [markdown]
# ## Endcoding

# %%
le = LabelEncoder()
data["Brand"] = le.fit_transform(data["Brand"])
data["Model"] = le.fit_transform(data["Model"])

categorical_cols = ["Fuel_Type", "Seller_Type", "Gear_Type"]
for i in categorical_cols :
    data[i] = le.fit_transform(data[i])
data.head(5)
# Out:
#    Brand First_Sell_Year Secondhand_Price   Mileage  Fuel_Type  Seller_Type  \
# 0     12            2007            60000   70000.0          3            0
# 1     12            2007           135000   50000.0          3            0
# 2      6            2012           600000  100000.0          2            0
# 3      9            2017           250000   46000.0          3            0
# 4      5            2014           450000  141000.0          2            0
#
#    Gear_Type  Past_Owner  Model Age
# 0          1           3     25  17
# 1          1           1     25  17
# 2          1           1     18  12
# 3          1           1     25   7
# 4          1           2     25  10

# %% [markdown]
# ## Normalize

# %% [raw]
# features = ["Brand", "First_Sell_Year", "Mileage", "Fuel_Type",
#            "Seller_Type", "Gear_Type", "Past_Owner", "Model", "Age"]
# label = "Secondhand_Price"

# %%
features = ["Brand", "First_Sell_Year", "Mileage", "Fuel_Type", 
           "Seller_Type", "Gear_Type", "Age"]
label = "Secondhand_Price"

# %%
X = data[features]
y = data[label]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
# แบ่ง train set เป็น train และ validation
X_train_sub, X_val, y_train_sub, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)


scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_sub)

# Normalize ชุด Test ด้วย Scaler จากชุด Train
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsRegressor(n_neighbors=4)

# Cross-validation (k=5)
scores = cross_val_score(knn, X_train_scaled, y_train_sub, cv=5)

# ดูคะแนนเฉลี่ย
print("Cross-validation accuracy:", scores.mean())
# Out:
# Cross-validation accuracy: 0.5651819181880159

# %% [markdown]
# # Training Model

# %% [markdown]
# # Hyperparameter tuning
